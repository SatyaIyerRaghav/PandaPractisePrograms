# %% [markdown]
# <a href="https://colab.research.google.com/github/SatyaIyerRaghav/PandaPractisePrograms/blob/main/Data__Exploratory_Analysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd , numpy as np

# %%
inp0 = pd.read_csv('bank_marketing_updated_v1.csv')
inp0.head()
# Out:
# <ipython-input-12-3019dda8d686>:1: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   inp0 = pd.read_csv('bank_marketing_updated_v1.csv')
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
#                                    Unnamed: 6 Unnamed: 7  \
# 0  particular customer before targeted or not        NaN
# 1                                    targeted    default
# 2                                         yes         no
# 3                                         yes         no
# 4                                         yes         no
#
#                            Unnamed: 8 Unnamed: 9   Unnamed: 10 Unnamed: 11  \
# 0  Loan types: loans or housing loans        NaN  Contact type         NaN
# 1                             housing       loan       contact         day
# 2                                 yes         no       unknown           5
# 3                                 yes         no       unknown           5
# 4                                 yes        yes       unknown           5
#
#         Unnamed: 12       Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0  month of contact  duration of call         NaN         NaN         NaN
# 1             month          duration    campaign       pdays    previous
# 2         may, 2017           261 sec           1          -1           0
# 3         may, 2017           151 sec           1          -1           0
# 4         may, 2017            76 sec           1          -1           0
#
#                    Unnamed: 17                              Unnamed: 18
# 0  outcome of previous contact  response of customer after call happned
# 1                     poutcome                                 response
# 2                      unknown                                       no
# 3                      unknown                                       no
# 4                      unknown                                       no

# %%
# We can clean the Data by skipping first two rows
inp0 = pd.read_csv('bank_marketing_updated_v1.csv',skiprows = 2)
inp0.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# 1     -1         0  unknown       no
# 2     -1         0  unknown       no
# 3     -1         0  unknown       no
# 4     -1         0  unknown       no

# %%
inp0['age'].mean() # 41 we can consider
# Out:
# 40.93565090394105

# %% [markdown]
# # Now we start cleaning of data

# %%
# step 1 : drop customerid as it not that much useful for analysis.

inp0.drop('customerid',axis = 1,inplace=True)
inp0.head(3)
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# 1  unknown       no
# 2  unknown       no

# %%
inp0.head(3)
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown  5.0  may, 2017  261 sec       1.0   -1.0       0.0
# 1     yes   no  unknown  5.0  may, 2017  151 sec       1.0   -1.0       0.0
# 2     yes  yes  unknown  5.0  may, 2017   76 sec       1.0   -1.0       0.0
#
#   poutcome response
# 0  unknown       no
# 1  unknown       no
# 2  unknown       no

# %%
inp0['jobs']= inp0['jobedu'].apply(lambda x : x.split(',')[0])
inp0.head(3)
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
#
#   poutcome response          jobs
# 0  unknown       no    management
# 1  unknown       no    technician
# 2  unknown       no  entrepreneur

# %%
inp0['Education']=inp0['jobedu'].apply(lambda x : x.split(',')[1])
inp0.head(3)
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
#
#   poutcome response          jobs  Education
# 0  unknown       no    management   tertiary
# 1  unknown       no    technician  secondary
# 2  unknown       no  entrepreneur  secondary

# %%
# now dropping the jobedu column
inp0.drop('jobedu',axis = 1,inplace = True)
inp0.head(3)
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
#
#        month duration  campaign  pdays  previous poutcome response  \
# 0  may, 2017  261 sec         1     -1         0  unknown       no
# 1  may, 2017  151 sec         1     -1         0  unknown       no
# 2  may, 2017   76 sec         1     -1         0  unknown       no
#
#            jobs  Education
# 0    management   tertiary
# 1    technician  secondary
# 2  entrepreneur  secondary

# %%
# Now clean the month coloumn .As we can see 2017 is most common .So we will extract first value for better analysis.

#inp0['month']=inp0['month'].apply(lambda x : x.split(',')[0])

# %%
#check the data for month feild
inp0.month.dtypes
# Out:
# dtype('O')

# %%
inp0.month.value_counts()
# Out:
# may, 2017    13747
# jul, 2017     6888
# aug, 2017     6240
# jun, 2017     5335
# nov, 2017     3968
# apr, 2017     2931
# feb, 2017     2646
# jan, 2017     1402
# oct, 2017      738
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: month, dtype: int64

# %%
inp0.month.mode()[0]
# Out:
# 'may, 2017'

# %%
# using fillna method we fill all the Null values of month column
inp0['month'] = inp0['month'].fillna(inp0.month.mode()[0])

# %%
inp0.month.isnull().sum()
# Out:
# 0

# %%
# now we finally fetch the month 
inp0['month']=inp0['month'].apply(lambda x : x.split(',')[0]) 
inp0.head(3)
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
#
#   month duration  campaign  pdays  previous poutcome response          jobs  \
# 0   may  261 sec         1     -1         0  unknown       no    management
# 1   may  151 sec         1     -1         0  unknown       no    technician
# 2   may   76 sec         1     -1         0  unknown       no  entrepreneur
#
#    Education
# 0   tertiary
# 1  secondary
# 2  secondary

# %%
inp0.isnull().sum()
# Out:
# age          20
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response     30
# jobs          0
# Education     0
# dtype: int64

# %%
# Step 3 : Clean age from null values by elimination method using quantifiers
inp1 = inp0[~inp0.age.isnull()].copy()
inp1.age.isnull().sum()
# Out:
# 0

# %%
# check for pdays as it contains -1 value ,ie knowingly we have to substitute NaN for these rows.
inp1.pdays.describe()
# Out:
# count    45191.000000
# mean        40.181253
# std        100.074099
# min         -1.000000
# 25%         -1.000000
# 50%         -1.000000
# 75%         -1.000000
# max        871.000000
# Name: pdays, dtype: float64

# %%
# using loc method we replace -1 with Nan val
inp1.loc[inp1.pdays<0,"pdays"] = np.NaN

# %%
inp1.pdays.describe()
# Out:
# count    8252.000000
# mean      224.523752
# std       115.202715
# min         1.000000
# 25%       133.000000
# 50%       194.500000
# 75%       327.000000
# max       871.000000
# Name: pdays, dtype: float64

# %%
inp1.isnull().sum()
# Out:
# age              0
# salary           0
# balance          0
# marital          0
# targeted         0
# default          0
# housing          0
# loan             0
# contact          0
# day              0
# month            0
# duration         0
# campaign         0
# pdays        36939
# previous         0
# poutcome         0
# response        30
# jobs             0
# Education        0
# dtype: int64

# %%
inp1.response.describe()
# Out:
# count     45161
# unique        2
# top          no
# freq      39876
# Name: response, dtype: object

# %%
inp1.response.value_counts()
# Out:
# no     39876
# yes     5285
# Name: response, dtype: int64

# %%
inp1.response.isnull().sum()/45191
# Out:
# 0.0006638489964816003

# %%
inp1.shape
# Out:
# (45191, 19)

# %%
inp1.head(3)
# Out:
#     age  salary  balance  marital targeted default housing loan  contact  day  \
# 0  58.0  100000     2143  married      yes      no     yes   no  unknown    5
# 1  44.0   60000       29   single      yes      no     yes   no  unknown    5
# 2  33.0  120000        2  married      yes      no     yes  yes  unknown    5
#
#   month duration  campaign  pdays  previous poutcome response          jobs  \
# 0   may  261 sec         1    NaN         0  unknown       no    management
# 1   may  151 sec         1    NaN         0  unknown       no    technician
# 2   may   76 sec         1    NaN         0  unknown       no  entrepreneur
#
#    Education
# 0   tertiary
# 1  secondary
# 2  secondary

# %%
inp1.salary.describe()
# Out:
# count     45191.000000
# mean      57005.974641
# std       32084.253154
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(inp1.salary)
plt.show()

# %%
plt.boxplot(inp1.salary)
plt.show()

# %%
inp1.duration.value_counts()
# Out:
# 1.5 min                 138
# 1.68333333333333 min    129
# 2.06666666666667 min    129
# 1.73333333333333 min    127
# 2.03333333333333 min    127
#                        ...
# 1500 sec                  1
# 22.1666666666667 min      1
# 868 sec                   1
# 1269 sec                  1
# 16.2833333333333 min      1
# Name: duration, Length: 2646, dtype: int64

# %%
inp1.duration = inp1.duration.apply(lambda x : float(x.split()[0])/60 if x.find("sec")>0 else float(x.split()[0]))

# %%
inp1.duration.describe()
# Out:
# count    45191.000000
# mean         4.303030
# std          4.292739
# min          0.000000
# 25%          1.716667
# 50%          3.000000
# 75%          5.316667
# max         81.966667
# Name: duration, dtype: float64
