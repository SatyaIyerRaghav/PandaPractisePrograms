# %% [markdown]
# <a href="https://colab.research.google.com/github/SatyaIyerRaghav/PandaPractisePrograms/blob/main/Data_Visualisation_Graded_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df1 = pd.read_csv('Marks.csv')
df1.head()
# Out:
#    Score A  Score B  Score C  Score D
# 0    230.1     37.8     69.2     22.1
# 1     44.5     39.3     45.1     10.4
# 2     17.2     45.9     69.3     12.0
# 3    151.5     41.3     58.5     16.5
# 4    180.8     10.8     58.4     17.9

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
df1.dtypes

# %%
#Your code here
plt.hist(df1['Score A'],bins=6)
plt.show()

#option D

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here
plt.boxplot(df1['Score C'])
plt.show()
#option D

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 =pd.read_csv('superstore.csv')
df2.head()
# Out:
#          Order ID       Ship Mode    Segment Region       Product ID  \
# 0  CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1  CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2  CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3  US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4  US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
#
#       Sales  Quantity Discount    Profit
# 0  261.9600         2       0%   41.9136
# 1  731.9400         3       0%  219.5820
# 2   14.6200         2       0%    6.8714
# 3  957.5775         5    0.45% -383.0310
# 4   22.3680         2    0.20%    2.5164

# %%
df2.shape
# Out:
# (9994, 9)

# %%
df2.dtypes
# Out:
# Order ID       object
# Ship Mode      object
# Segment        object
# Region         object
# Product ID     object
# Sales         float64
# Quantity        int64
# Discount       object
# Profit        float64
# dtype: object

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
#Your code here
df2['Ship Mode'].value_counts().plot.pie()
plt.show()

#option:a. Stamdard Class

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
df2.head()

#option a Central
# Out:
# 0.15620272163297977

# %%
#Your code here
#inp1[inp1.Price>0].Price.plot.box()
df2.Discount.value_counts()
df2.Discount.dtypes
df2.dtypes
# Out:
# Order ID       object
# Ship Mode      object
# Segment        object
# Region         object
# Product ID     object
# Sales         float64
# Quantity        int64
# Discount       object
# Profit        float64
# dtype: object

# %%
df2.Discount = df2['Discount'].apply(lambda x: "0" if x==0  else float(x.replace('%','')))

# %%
df2.Discount.value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
df2.Discount.dtypes
# Out:
# dtype('float64')

# %%
sns.barplot(data = df2, x = 'Region', y = 'Discount', estimator=np.mean)
plt.show()

# %%
df3 = df2[(df2.Profit < 0) & (df2.Sales < 15000)]
sns.jointplot(df3 , x='Sales', y='Profit')
plt.show()

# %%
df3 = df2[(df2.Profit < 0) | (df2.Sales < 15000)]
sns.jointplot(df3, x='Sales', y= 'Profit')
plt.show()

# %%
df3= df2[(df2.Profit > 0) & (df2.Sales < 15000)]
sns.jointplot(df3 ,x= 'Sales', y = 'Profit')
plt.show()

# %%
df3 = df2[(df2.Profit < 0) | (df2.Sales > 15000)]
sns.jointplot(df3,x='Sales', y='Profit')
plt.show()

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales', estimator = np.mean)
sns.barplot(data = df2, x = 'Segment', y = 'Sales')
plt.show()

# %%
sns.barplot(data = df2, x = 'Segment', y = 'Sales', estimator = np.avg)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-fa2835d87dec> in <cell line: 1>()
# ----> 1 sns.barplot(data = df2, x = 'Segment', y = 'Sales', estimator = np.avg)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     313             return Tester
#     314
# --> 315         raise AttributeError("module {!r} has no attribute "
#     316                              "{!r}".format(__name__, attr))
#     317
#
# AttributeError: module 'numpy' has no attribute 'avg'
